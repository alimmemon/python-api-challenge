# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
latitude= []
longitude= []
windspeed= []
max_temperature= []
cloudiness= []
humidity= []
countries=[]
cities_list=[]
date=[]


units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

units = "metric"

for i in range(len(cities)):
    
    city= cities[i]
    
    try:
        print("Beginning Data Retrieval")
        weather_json = requests.get(query_url + city).json()
        # weather_json which lists data in key-value pairs
        # I indexed weather_json using its keys
        # weather_json doesn't have indexes (unstructured), it has keys
        latitude.append(weather_json['coord']['lat'])
        longitude.append(weather_json['coord']['lon'])
        windspeed.append(weather_json['wind']['speed'])
        cloudiness.append(weather_json['clouds']['all'])
        max_temperature.append(weather_json['main']['temp_max'])
        humidity.append(weather_json['main']['humidity'])
        countries.append(weather_json['sys']['country'])
        cities_list.append(city)
        date.append(weather_json['dt'])
        
        print("----------------------------------\n")
        print(f"Processing Record {i} of Set 1 | {city}")

    except:
        
        print(f"City {city} not found. Skipping...\n")
# Out:
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 0 of Set 1 | boca do acre
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 1 of Set 1 | tuy hoa
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 2 of Set 1 | biltine
# Beginning Data Retrieval
# City vaitupu not found. Skipping...
#
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 4 of Set 1 | port alfred
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 5 of Set 1 | pahasu
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 6 of Set 1 | safranbolu
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 7 of Set 1 | khatanga
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 8 of Set 1 | tra vinh
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 9 of Set 1 | mataura
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 10 of Set 1 | arraial do cabo
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 11 of Set 1 | tuatapere
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 12 of Set 1 | gigmoto
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 13 of Set 1 | airai
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 14 of Set 1 | nemuro
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 15 of Set 1 | jutai
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 16 of Set 1 | zaozerne
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 17 of Set 1 | carranglan
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 18 of Set 1 | vaini
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 19 of Set 1 | narsipatnam
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 20 of Set 1 | entre rios
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 21 of Set 1 | guarapari
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 22 of Set 1 | ocana
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 23 of Set 1 | hermanus
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 24 of Set 1 | albany
# Beginning Data Retrieval
# City illoqqortoormiut not found. Skipping...
#
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 26 of Set 1 | ayan
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 27 of Set 1 | busselton
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 28 of Set 1 | cluses
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 29 of Set 1 | roswell
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 30 of Set 1 | derzhavinsk
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 31 of Set 1 | saint george
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 32 of Set 1 | tasiilaq
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 33 of Set 1 | hasaki
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 34 of Set 1 | punta arenas
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 35 of Set 1 | vyazemskiy
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 36 of Set 1 | port elizabeth
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 37 of Set 1 | ushuaia
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 38 of Set 1 | opuwo
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 39 of Set 1 | hilo
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 40 of Set 1 | mar del plata
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 41 of Set 1 | khash
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 42 of Set 1 | shimoda
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 43 of Set 1 | lebu
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 44 of Set 1 | sao filipe
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 45 of Set 1 | bluff
# Beginning Data Retrieval
# City mys shmidta not found. Skipping...
#
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 47 of Set 1 | coos bay
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 48 of Set 1 | ribeira grande
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 49 of Set 1 | hami
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 50 of Set 1 | severo-kurilsk
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 51 of Set 1 | chuy
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 52 of Set 1 | gigant
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 53 of Set 1 | kota bahru
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 54 of Set 1 | bredasdorp
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 55 of Set 1 | port hardy
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 56 of Set 1 | faanui
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 587 of Set 1 | ashtabula
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 588 of Set 1 | kovvur
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 589 of Set 1 | baykalsk
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 590 of Set 1 | tucurui
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 591 of Set 1 | tamiahua
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 592 of Set 1 | orange cove
# Beginning Data Retrieval
# City tidore not found. Skipping...
#
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 594 of Set 1 | raudeberg
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 595 of Set 1 | ziyang
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 596 of Set 1 | abong mbang
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 597 of Set 1 | gordeyevka
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 598 of Set 1 | sechura
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 599 of Set 1 | havre-saint-pierre
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 600 of Set 1 | krasnyy luch
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 601 of Set 1 | wanning
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 602 of Set 1 | la primavera
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 603 of Set 1 | jaunjelgava
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 604 of Set 1 | ancud
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 605 of Set 1 | jaciara
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 606 of Set 1 | zhangye
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 607 of Set 1 | chara
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 608 of Set 1 | hualmay
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 609 of Set 1 | bayir
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 610 of Set 1 | xining
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 611 of Set 1 | luzhou
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 612 of Set 1 | atasu
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 613 of Set 1 | maple creek
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 614 of Set 1 | pimampiro
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 615 of Set 1 | te anau
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 616 of Set 1 | linxia
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 617 of Set 1 | nouadhibou
# Beginning Data Retrieval
# ----------------------------------
#
# Processing Record 618 of Set 1 | puga

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df =pd.DataFrame({"Cities": cities_list,
                          "Cloudiness": cloudiness,
                         "Country":countries,          
                "Date": date,
                "Humidity": humidity,
                "Latitude" : latitude,
              "Longitude": longitude,
              "Max Temperature": max_temperature,
                "Windspeed": windspeed,
                         })


weather_df.to_csv("weather_data.csv", index=False)

# %%
# Without scoop_price

weather_df
# Out:
#            Cities  Cloudiness Country        Date  Humidity  Latitude  \
# 0    boca do acre          59      BR  1586665308        91     -8.75
# 1         tuy hoa          80      VN  1586665308        65     13.08
# 2         biltine          99      TD  1586665308        15     14.53
# 3     port alfred          37      ZA  1586665308        81    -33.59
# 4          pahasu          20      IN  1586665309        21     28.18
# ..            ...         ...     ...         ...       ...       ...
# 565     pimampiro          99      EC  1586665380        44      0.40
# 566       te anau          80      NZ  1586665380        75    -45.42
# 567        linxia          19      CN  1586665380        19     35.60
# 568    nouadhibou           0      MR  1586665380        72     20.93
# 569          puga          17      MX  1586665380        49     21.58
#
#      Longitude  Max Temperature  Windspeed
# 0       -67.40            23.38       0.31
# 1       109.30            29.04       1.62
# 2        20.92            25.22       7.01
# 3        26.89            18.33       2.24
# 4        78.05            31.31       3.91
# ..         ...              ...        ...
# 565     -77.97            16.76       0.20
# 566     167.72            13.55       1.66
# 567     103.21            10.13       2.41
# 568     -17.03            19.00       9.80
# 569    -104.82            16.66       0.39
#
# [570 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(latitude, max_temperature, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(latitude, humidity, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(latitude, cloudiness, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.title("City Latitude vs. Cloudiness (04/11/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(latitude, windspeed, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.title("City Latitude vs. Wind Peed (04/11/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hemisphere= weather_df.loc[(weather_df["Latitude"] >= 0) , :]

x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Max Temperature"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Max Temperature vs Northern Hemisphere Latitude")

linregress =(x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,-15),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hemisphere= weather_df.loc[(weather_df["Latitude"] < 0) , :]

x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Max Temperature"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Max Temperature vs Southern Hemisphere Latitude")

linregress =(x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-56,31),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Humidity"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Northern Hemisphere Latitude")

linregress= (x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Humidity"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Southern Hemisphere Latitude")

linregress= (x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Cloudiness"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Northern Hemisphere Latitude")

linregress= (x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,60),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Cloudiness"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Southern Hemisphere Latitude")

linregress= (x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,45),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Windspeed"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs Northern Hemisphere Latitude")

linregress= (x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,20),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Windspeed"]

plt.scatter(x_values, y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs Southern Hemisphere Latitude")

linregress =(x_values, y_values, slope, intercept, rvalue, pvalue, stderr) 

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-squared value is: {rvalue}.")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,14),fontsize=15,color="red")
plt.show()
# Out:
# The r-squared value is: 0.6549640810280678.
